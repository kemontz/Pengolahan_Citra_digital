# %% [markdown]
# <a href="https://colab.research.google.com/github/kemontz/Pengolahan_Citra_digital/blob/main/PCD_Salt_and_Paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# libraries
import urllib.request
import cv2
import matplotlib.pyplot as plt
import numpy as np
# orginal image
urllib.request.urlretrieve('https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png', "Lenna.png")
# Out:
# ('Lenna.png', <http.client.HTTPMessage at 0x78d83a6791b0>)

# %%
img = cv2.imread('Lenna.png', cv2.IMREAD_GRAYSCALE)
img = img/255

# %%
plt.imshow(img, cmap='gray')
plt.show()

# %%
# blank image
x,y = img.shape
g = np.zeros((x,y), dtype=np.float32)
# salt and pepper amount
pepper = 0.1
salt = 0.95

# %%
import cv2
import numpy as np
# ... (your existing code) ...

for i in range(x):
    for j in range(y):
        rdn = np.random.random()
        if rdn < pepper:
            g[i][j] = 0
        elif rdn > salt:
            g[i][j] = 1
        else:
            g[i][j] = img[i][j]

# If using in a standard Python environment with OpenCV installed:
# cv2.imshow('Image with Salt and Pepper Noise', g)

# If using in Google Colab or a similar environment:
from google.colab.patches import cv2_imshow # Import cv2_imshow from google.colab.patches
cv2_imshow(g) # Use cv2_imshow to display the image


cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
# (optional) save the image
from skimage import img_as_ubyte
cv2.imwrite('5percent.jpg', img_as_ubyte(g))
# Out:
# True
